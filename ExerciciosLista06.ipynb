# %% [markdown]
# <a href="https://colab.research.google.com/github/Artur-DesenvolvimentoWEB/ExerciciosPYTHON/blob/main/ExerciciosLista06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Artur Campos Batista - 2014290012
# Lista 6

import seaborn as sn #importando biblioteca estatistica
import pandas as pd 
import matplotlib.pyplot as plt
 
data = {'x':[60,58,73,51,54,75,48,72,75,83,62,52],'y':[80,62,70,83,62,92,79,88,54,82,64,69]}
df = pd.DataFrame(data,columns=['x', 'y'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()
print("A matrix de correlação é:")
print(corrMatrix)
print("------------------------------------------------")
print("O coeficiente arredondado encontrado é: r = 0.17")

# %% [markdown]
# # Disciplina: Probabilidade e Estatística
# # Aluno: Artur Campos Batista - 2014290012
# # Lista 6 - QUESTÃO 2
#
# Numa  amostra  aleatória  de  n=12  livros  da  Biblioteca  Central,  encontramos  r=  0,207 entre a idade da edição e o número de páginas do livro. a) O que se pode dizer com base no valor deste coeficiente de correlação?
#
#   *Resposta:* **Que há uma correlação desprezível entre  a  idade  da  edição e o número de páginas do livro**;
#
#   Interpretando 'r':
#
#   •0 a 0.3 positivo ou negativo indica uma correlação desprezível.

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Artur Campos Batista - 2014290012
# Lista 6

import seaborn as sn #importando biblioteca estatistica
import pandas as pd 
import matplotlib.pyplot as plt
 
data = {'x':[2,3,4,5,4,6,7,8,8,10],'y':[48,50,56,52,43,60,62,58,64,72]}
df = pd.DataFrame(data,columns=['x', 'y'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()
print("A matrix de correlação é:")
print(corrMatrix)
print("-----------------------------------------------")
print("O coeficiente arredondado encontrado é: r = 0.9")
print("Logo temos uma indicação de que há uma correlação forte positiva:")
print("•0.7 a 0.9 positivo ou negativo indica uma correlação forte.")

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Artur Campos Batista - 2014290012
# Lista 6

import seaborn as sn #importando biblioteca estatistica
import pandas as pd 
import matplotlib.pyplot as plt
 
data = {'x':[12,16,18,20,28,30,40,48,50,54],'y':[7.2,7.4,7.0,6.5,6.6,6.7,6.0,5.6,6.0,5.5]}
df = pd.DataFrame(data,columns=['x', 'y'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()
print("A matrix de correlação é:")
print(corrMatrix)
print("-----------------------------------------------------")
print("O coeficiente arredondado encontrado é: r = -0.94")
print("Logo temos uma indicação de que há uma correlação muito forte negativa:")
print("•0.9 para mais ou para menos indica uma correlação muito forte.")

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Artur Campos Batista - 2014290012
# Lista 6
import statistics
import seaborn as sn #importando biblioteca seaborn
import pandas as pd #importando biblioteca pandas
import matplotlib.pyplot as plt #importando biblioteca matplotlib.pyplot

lista1 = [10.0,8.0,13.0,9.0,11.0,14.0,6.0,4.0,12.0,7.0,5.0] #declarando todas as listas x e y dos 4 conjuntos
lista2 = [8.04,6.95,7.58,8.81,8.33,9.96,7.24,4.26,10.84,4.82,5.68]
lista3 = [10.0,8.0,13.0,9.0,11.0,14.0,6.0,4.0,12.0,7.0,5.0]
lista4 = [9.14,8.14,8.74,8.77,9.26,8.1,6.13,3.1,9.13,7.26,4.74]
lista5 = [10.0,8.0,13.0,9.0,11.0,14.0,6.0,4.0,12.0,7.0,5.0]
lista6 = [7.46,6.77,12.74,7.11,7.81,8.84,6.08,5.39,8.15,6.42,5.73]
lista7 = [8,8,8,8,8,8,8,19,8,8,8]
lista8 = [6.58,5.76,7.71,8.84,8.47,7.04,5.25,12.5,5.56,7.91,6.89]

 
data = {'lista1':lista1, 'lista2':lista2}

df = pd.DataFrame(data,columns=['lista1', 'lista2'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

media1 = sum(lista1) / len(lista1) #formula de obtenção da média
print("A média de X no Conjunto 1 é de:", media1)

desvio1 = statistics.stdev(lista1)#utilizando o modulo statistics para se obter o desvio padrão
print("E o desvio padrão de X no Conjunto 1 é de: %.5f" %desvio1)

media2 = sum(lista2) / len(lista2) #formula de obtenção da média
print("A média de Y no Conjunto 1 é de:", media2)

desvio2 = statistics.stdev(lista2)#utilizando o modulo statistics para se obter o desvio padrão
print("E o desvio padrão de Y no Conjunto 1 é de: %.5f" %desvio2)
print("A matrix de correlação é:")
print(corrMatrix)

#-------------------------------------------------------------------------------------

data = {'lista3':lista3, 'lista4':lista4}

df = pd.DataFrame(data,columns=['lista3', 'lista4'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

media1 = sum(lista3) / len(lista3) #formula de obtenção da média
print("A média de X no Conjunto 2 é de:", media1)

desvio1 = statistics.stdev(lista3)#utilizando o modulo statistics para se obter o desvio padrão
print("E o desvio padrão de X no Conjunto 2 é de: %.5f" %desvio1)

media2 = sum(lista4) / len(lista4)
print("A média de Y no Conjunto 2 é de:", media2)

desvio2 = statistics.stdev(lista4)#utilizando o modulo statistics para se obter o desvio padrão
print("E o desvio padrão de Y no Conjunto 2 é de: %.5f" %desvio2)
print("A matrix de correlação é:")
print(corrMatrix)

#-------------------------------------------------------------------------------------

data = {'lista5':lista5, 'lista6':lista6}

df = pd.DataFrame(data,columns=['lista5', 'lista6'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

media1 = sum(lista5) / len(lista5)#formula de obtenção da média
print("A média de X no Conjunto 3 é de:", media1)

desvio1 = statistics.stdev(lista5)#utilizando o modulo statistics para se obter o desvio padrão
print("E o desvio padrão de X no Conjunto 3 é de: %.5f" %desvio1)

media2 = sum(lista6) / len(lista6) #formula de obtenção da média
print("A média de Y no Conjunto 3 é de:", media2)

desvio2 = statistics.stdev(lista6)#utilizando o modulo statistics para se obter o desvio padrão
print("E o desvio padrão de Y no Conjunto 3 é de: %.5f" %desvio2)
print("A matrix de correlação é:")
print(corrMatrix)

#-------------------------------------------------------------------------------------

data = {'lista7':lista7, 'lista8':lista8}

df = pd.DataFrame(data,columns=['lista7', 'lista8'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

media1 = sum(lista7) / len(lista7)#formula de obtenção da média
print("A média de X no Conjunto 4 é de:", media1)

desvio1 = statistics.stdev(lista7)#utilizando o modulo statistics para se obter o desvio padrão
print("E o desvio padrão de X no Conjunto 4 é de: %.5f" %desvio1)

media2 = sum(lista8) / len(lista8)#formula de obtenção da média
print("A média de Y no Conjunto 4 é de:", media2)

desvio2 = statistics.stdev(lista8)#utilizando o modulo statistics para se obter o desvio padrão
print("E o desvio padrão de Y no Conjunto 4 é de: %.5f" %desvio2)
print("A matrix de correlação é:")
print(corrMatrix)

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: Artur Campos Batista - 2014290012
# Lista 6

import seaborn as sn #importando biblioteca seaborn
import pandas as pd #importando biblioteca pandas
import matplotlib.pyplot as plt #importando biblioteca matplotlib.pyplot

produtividade = [100,102,105,108,112,120] #declarando todas as listas x e y dos 4 conjuntos
alimentação = [4,5,1,3,6,2]
exercicios = [1,3,2,4,5,6]
rodizio = [3,1,2,6,4,5]

data = {'produtividade':produtividade, 'alimentação':alimentação}

df = pd.DataFrame(data,columns=['produtividade', 'alimentação'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()
print("*Todos os coeficientes apresentados são automaticamente arredondados, em conformidade com a impressão visual.")
#---------------------------------------------------------------
data = {'produtividade':produtividade, 'exercicios':exercicios}

df = pd.DataFrame(data,columns=['produtividade', 'exercicios'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()
print("*Todos os coeficientes apresentados são automaticamente arredondados, em conformidade com a impressão visual.")
#---------------------------------------------------------------
data = {'produtividade':produtividade, 'rodizio':rodizio}

df = pd.DataFrame(data,columns=['produtividade', 'rodizio'])
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

print("*Todos os coeficientes apresentados são automaticamente arredondados, em conformidade com a impressão visual.")
